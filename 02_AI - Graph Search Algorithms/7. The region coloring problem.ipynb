# %% [markdown]
# # The region coloring problem - Exercise
#
# Let's use the constraint satisfaction framework to solve a region coloring problem. Consider the following map:
#
# <img src="./resources/mapempty.png"  style="height: 400px"/>
#
# We have a few regions in the preceding figure that are labeled with fictional country names. Our goal is to color the map with four colors so that no adjacent countries have the same color.

# %% [markdown]
# First import the classes, define the variables (the names of the countries) and the possible values (colors) that every variable (country) can take. There are four colors: red, green, blue and gray.

# %%
from simpleai.search import CspProblem, backtrack

# Variables representing the countries
variables = ['Wakanda', 'Latveria', 'Genosha', 'Madripoor', 'Symkaria', 'Transia', 'Akima', 'Sokavia', 'Atlantis', 'Canaan', 'Murkatesh']

# Available colors
colors = ['Red', 'Green', 'Blue', 'Gray'] 

# Define the neighbors and integrate into the domains dictionary
domains = {country: colors for country in variables}

print(domains)
# Out:
# {'Wakanda': ['Red', 'Green', 'Blue', 'Gray'], 'Latveria': ['Red', 'Green', 'Blue', 'Gray'], 'Genosha': ['Red', 'Green', 'Blue', 'Gray'], 'Madripoor': ['Red', 'Green', 'Blue', 'Gray'], 'Symkaria': ['Red', 'Green', 'Blue', 'Gray'], 'Transia': ['Red', 'Green', 'Blue', 'Gray'], 'Akima': ['Red', 'Green', 'Blue', 'Gray'], 'Sokavia': ['Red', 'Green', 'Blue', 'Gray'], 'Atlantis': ['Red', 'Green', 'Blue', 'Gray'], 'Canaan': ['Red', 'Green', 'Blue', 'Gray'], 'Murkatesh': ['Red', 'Green', 'Blue', 'Gray']}

# %% [markdown]
# Define the constraint function that imposes that two neighbors should be colored differently. Apply the constraint for every pair of countries from the map above.

# %%
# neighbors = {
#     'Wakanda': ['Latveria', 'Madripoor'],
#     'Latveria': ['Wakanda', 'Genosha', 'Madripoor', 'Symkaria', 'Transia'],
#     'Genosha': ['Latveria', 'Transia', 'Akima'],
#     'Madripoor': ['Wakanda', 'Latveria', 'Symkaria', 'Atlantis', 'Sokavia'],
#     'Symkaria': ['Latveria', 'Madripoor', 'Transia', 'Atlantis', 'Canaan'],
#     'Transia': ['Genosha', 'Latveria', 'Symkaria', 'Akima', 'Canaan', 'Murkatesh'],
#     'Akima': ['Genosha', 'Transia', 'Murkatesh'],
#     'Sokavia': ['Atlantis', 'Madripoor'],
#     'Atlantis': ['Madripoor', 'Symkaria', 'Sokavia', 'Canaan'],
#     'Canaan': ['Atlantis', 'Symkaria', 'Transia', 'Murkatesh'],
#     'Murkatesh': ['Transia', 'Akima', 'Canaan']
#     }

neighbors = {
    'Wakanda': ['Latveria', 'Madripoor'],
    'Latveria': ['Genosha', 'Madripoor', 'Symkaria', 'Transia'],
    'Genosha': ['Transia', 'Akima'],
    'Madripoor': ['Symkaria', 'Atlantis', 'Sokavia'],
    'Symkaria': ['Transia', 'Atlantis', 'Canaan'],
    'Transia': [ 'Akima', 'Canaan', 'Murkatesh'],
    'Akima': ['Murkatesh'],
    'Sokavia': ['Atlantis'],
    'Atlantis': ['Canaan'],
    'Canaan': ['Murkatesh'],
    }

def constraint_func1(variables, values):
    out = values[0] != values[1]
    print(variables, values, out)
    return values[0] != values[1]


constraints = []

for country, neighbors_list in neighbors.items():
    for neighbor in neighbors_list:
        constraints.append((([country, neighbor]), constraint_func1))

  
problem = CspProblem(variables, domains, constraints)

output = backtrack(problem)
print(output)
# Out:
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Red') False
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Red') False
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Gray') True
# ('Latveria', 'Symkaria') ('Green', 'Green') False
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Green', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Green', 'Green') False
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Green', 'Green') False
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Green', 'Green') False
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Green', 'Gray') True
# ('Latveria', 'Genosha') ('Green', 'Green') False
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Blue') True
# ('Genosha', 'Akima') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Latveria', 'Symkaria') ('Green', 'Green') False
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Green', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Blue') False
# ('Genosha', 'Akima') ('Blue', 'Gray') True
# ('Genosha', 'Akima') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Gray') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Genosha', 'Transia') ('Blue', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Blue') False
# ('Genosha', 'Akima') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Genosha', 'Transia') ('Blue', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Blue') False
# ('Genosha', 'Akima') ('Blue', 'Gray') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Latveria', 'Transia') ('Green', 'Gray') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Gray', 'Gray') False
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Latveria', 'Genosha') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Gray', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Gray', 'Gray') False
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Green', 'Gray') True
# ('Genosha', 'Akima') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Gray', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Gray') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Gray', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Gray', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Green', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Green', 'Gray') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Blue', 'Gray') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Gray', 'Gray') False
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Gray', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Gray', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Green') True
# ('Genosha', 'Akima') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Green') True
# ('Genosha', 'Transia') ('Gray', 'Gray') False
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Gray') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Green', 'Gray') True
# ('Latveria', 'Symkaria') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Gray', 'Gray') False
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Gray', 'Green') True
# ('Latveria', 'Symkaria') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Green', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Latveria', 'Genosha') ('Gray', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Gray', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Gray', 'Green') True
# ('Latveria', 'Symkaria') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Latveria', 'Genosha') ('Gray', 'Green') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Gray', 'Green') True
# ('Latveria', 'Symkaria') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Madripoor') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Red', 'Gray') True
# ('Wakanda', 'Madripoor') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Latveria', 'Transia') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Red') False
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Wakanda', 'Latveria') ('Green', 'Green') False
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Red') False
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Red', 'Red') False
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Red', 'Red') False
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Red', 'Red') False
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Gray') True
# ('Latveria', 'Genosha') ('Red', 'Red') False
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Genosha', 'Akima') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Red') False
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Blue') False
# ('Genosha', 'Akima') ('Blue', 'Gray') True
# ('Genosha', 'Akima') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Gray') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Genosha', 'Transia') ('Blue', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Blue') False
# ('Genosha', 'Akima') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Genosha', 'Transia') ('Blue', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Blue') False
# ('Genosha', 'Akima') ('Blue', 'Gray') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Gray', 'Gray') False
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Blue', 'Blue') False
# ('Symkaria', 'Canaan') ('Blue', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Blue') False
# ('Symkaria', 'Atlantis') ('Blue', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Symkaria', 'Transia') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Akima') ('Gray', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Gray', 'Gray') False
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Gray') True
# ('Genosha', 'Akima') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Gray', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Gray') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Gray') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Blue', 'Gray') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Gray', 'Gray') False
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Gray') True
# ('Wakanda', 'Latveria') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Gray') True
# ('Genosha', 'Transia') ('Gray', 'Red') True
# ('Genosha', 'Transia') ('Gray', 'Gray') False
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Latveria', 'Transia') ('Gray', 'Gray') False
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Latveria', 'Genosha') ('Gray', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Gray', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Latveria', 'Genosha') ('Gray', 'Red') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Madripoor') ('Gray', 'Blue') True
# ('Wakanda', 'Latveria') ('Green', 'Gray') True
# ('Wakanda', 'Madripoor') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Latveria', 'Transia') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Gray') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Red') False
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Gray', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Wakanda', 'Latveria') ('Blue', 'Red') True
# ('Wakanda', 'Latveria') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Blue', 'Blue') False
# ('Wakanda', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Gray') True
# ('Latveria', 'Symkaria') ('Red', 'Red') False
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Red', 'Gray') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Red', 'Gray') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Gray', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Gray', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Green') True
# ...
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Genosha') ('Red', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Genosha', 'Transia') ('Green', 'Blue') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Green') False
# ('Genosha', 'Akima') ('Green', 'Blue') True
# ('Latveria', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Latveria') ('Gray', 'Red') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Red') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Green', 'Green') False
# ('Symkaria', 'Canaan') ('Green', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Green') False
# ('Symkaria', 'Atlantis') ('Green', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Latveria', 'Symkaria') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Symkaria', 'Transia') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Akima') ('Blue', 'Green') True
# ('Latveria', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Madripoor') ('Red', 'Green') True
# ('Latveria', 'Madripoor') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Latveria', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Genosha') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Green') False
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Green', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Blue') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Blue') True
# ('Latveria', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Latveria', 'Genosha') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Blue') True
# ('Symkaria', 'Canaan') ('Blue', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Green', 'Red') True
# ('Latveria', 'Symkaria') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Akima') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Green', 'Blue') True
# ('Wakanda', 'Latveria') ('Gray', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Blue') True
# ('Genosha', 'Transia') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Blue', 'Blue') False
# ('Latveria', 'Transia') ('Green', 'Red') True
# ('Latveria', 'Genosha') ('Green', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Blue') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Blue') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Transia') ('Blue', 'Blue') False
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Green') True
# ('Genosha', 'Akima') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Green', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Green', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Genosha', 'Transia') ('Red', 'Green') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Genosha', 'Akima') ('Red', 'Red') False
# ('Genosha', 'Akima') ('Red', 'Green') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Genosha', 'Transia') ('Red', 'Red') False
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Latveria', 'Genosha') ('Blue', 'Red') True
# ('Symkaria', 'Transia') ('Green', 'Green') False
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Red', 'Red') False
# ('Symkaria', 'Canaan') ('Red', 'Green') True
# ('Symkaria', 'Canaan') ('Green', 'Red') True
# ('Symkaria', 'Atlantis') ('Red', 'Red') False
# ('Symkaria', 'Atlantis') ('Red', 'Green') True
# ('Symkaria', 'Atlantis') ('Green', 'Red') True
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Red') True
# ('Latveria', 'Symkaria') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# ('Symkaria', 'Transia') ('Red', 'Green') True
# ('Symkaria', 'Transia') ('Green', 'Red') True
# ('Genosha', 'Akima') ('Green', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Red') True
# ('Latveria', 'Madripoor') ('Blue', 'Green') True
# ('Wakanda', 'Latveria') ('Gray', 'Blue') True
# ('Wakanda', 'Madripoor') ('Gray', 'Red') True
# ('Wakanda', 'Madripoor') ('Gray', 'Green') True
# ('Genosha', 'Transia') ('Green', 'Red') True
# ('Genosha', 'Transia') ('Green', 'Green') False
# ('Latveria', 'Transia') ('Blue', 'Red') True
# ('Latveria', 'Genosha') ('Blue', 'Green') True
# ('Symkaria', 'Transia') ('Red', 'Red') False
# None

# %% [markdown]
# And finaly search for a solution and print it (something like this: "Wakanda ==> red, ..."). You can iterate over the solution as follows
#
# ```python
# for country, color in output.items():
# ```

# %%
from constraint import Problem, AllDifferentConstraint

# Variables representing the countries
variables = ['Wakanda', 'Latveria', 'Genosha', 'Madripoor', 'Symkaria', 'Transia', 'Akima', 'Sokavia', 'Atlantis', 'Canaan', 'Murkatesh']

# Available colors
colors = ['Red', 'Green', 'Blue', 'Gray']

# Create a problem instance
problem = Problem()

# Add variables and their domains
for variable in variables:
    problem.addVariable(variable, colors)

# Define the neighbors
neighbors = {
    'Wakanda': ['Latveria', 'Madripoor'],
    'Latveria': ['Wakanda', 'Genosha', 'Madripoor', 'Symkaria', 'Transia'],
    'Genosha': ['Latveria', 'Transia', 'Akima'],
    'Madripoor': ['Wakanda', 'Latveria', 'Symkaria', 'Atlantis', 'Sokavia'],
    'Symkaria': ['Latveria', 'Madripoor', 'Transia', 'Atlantis', 'Canaan'],
    'Transia': ['Latveria', 'Genosha', 'Symkaria', 'Akima', 'Canaan', 'Murkatesh'],
    'Akima': ['Genosha', 'Transia', 'Murkatesh'],
    'Sokavia': ['Madripoor', 'Atlantis'],
    'Atlantis': ['Madripoor', 'Symkaria', 'Sokavia', 'Canaan'],
    'Canaan': ['Symkaria', 'Transia', 'Atlantis', 'Murkatesh'],
    'Murkatesh': ['Transia', 'Akima', 'Canaan']
}

# Add constraints
for country, neighbors_list in neighbors.items():
    for neighbor in neighbors_list:
        problem.addConstraint(lambda a, b: a != b, (country, neighbor))

# Solve the problem
solution = problem.getSolution()

if solution:
    print("Solution:")
    for country, color in solution.items():
        print(f"{country}: {color}")
else:
    print("No solution found.")
# Out:
# Solution:
# Transia: Gray
# Latveria: Blue
# Symkaria: Green
# Madripoor: Gray
# Atlantis: Blue
# Canaan: Red
# Genosha: Green
# Akima: Blue
# Murkatesh: Green
# Sokavia: Green
# Wakanda: Green

# %% [markdown]
# Use Paint or Photoshop to color the map with the colors from the solution and check that no two adjacent countries have the same color.
#
# Would it be possible to color the map with only three colors?
