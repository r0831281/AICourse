# %% [markdown]
# # Will John play tennis?
#
# In this first example we will use the example from the video and try to predict if John will play tennis on a particular day? We will use scikit-learn to build the decision tree. We will visualize the tree using Pydotplus and Graphviz. Graphviz is a tool for drawing graphics using dot files. Pydotplus is a module to Graphviz’s Dot language.

# %% [markdown]
# First install Graphviz and Pydotplus:
#
# 1. Download Graphviz and Install https://graphviz.gitlab.io/_pages/Download/Download_windows.html
#
#
# 2. !pip install graphviz
#    !pip install pydotplus
#
#
# 3. Add the graphviz installed path (C:...\graphviz\bin) to Control Panel > System and Security > System > Advanced System Settings > Environment Variables > Path > Edit > New
#
#
# 4. Very Important: Restart your Jupyter Notebook/machine.

# %%
# !pip install graphviz
# !pip install pydotplus
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# !pip install graphviz
# !pip install pydotplus
# Out:
# Requirement already satisfied: graphviz in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (0.20.3)
# Requirement already satisfied: pydotplus in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pydotplus) (3.1.2)
# Requirement already satisfied: numpy in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: graphviz in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (0.20.3)
# Requirement already satisfied: pydotplus in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pydotplus) (3.1.2)

# %% [markdown]
# ## 1. Import packages and classes
#
# The first step is to import the packages:

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %% [markdown]
# ## 2. Provide the data
#
# The second step is defining the data to work with. Below you will find the data from the example in Excel-format. We will load the data, build the tree and at the end, we will try to predict if John will play tennis on a rainy day with high humidity and weak wind.
#
# <img src="./resources/tennis.png" style="height: 300px"/>
#
# Let's import the data using pandas:

# %%
# load dataset
tennis_df = pd.read_csv("resources/tennis1.csv", sep=';')

# %% [markdown]
# We can then print the imported values:

# %%
print(tennis_df)
# Out:
#     day   outlook humidity    wind play
# 0    d1     sunny     high    weak   no
# 1    d2     sunny     high  strong   no
# 2    d3  overcast     high    weak  yes
# 3    d4      rain     high    weak  yes
# 4    d5      rain   normal    weak  yes
# 5    d6      rain   normal  strong   no
# 6    d7  overcast   normal  strong  yes
# 7    d8     sunny     high    weak   no
# 8    d9     sunny   normal    weak  yes
# 9   d10      rain   normal    weak  yes
# 10  d11     sunny   normal  strong  yes
# 11  d12  overcast     high  strong  yes
# 12  d13  overcast   normal    weak  yes
# 13  d14      rain     high  strong   no

# %% [markdown]
# ## 3. Split the data
#
# Given input features: *outlook, humidity and wind* we will predict if John will *play* or not. Let's split the features and the target variable:

# %%
# split dataset in features and target variable

feature_cols = ['outlook', 'humidity', 'wind']

X = tennis_df[feature_cols]
y = tennis_df[['play']] # target variable

# %%
print(X)
# Out:
#      outlook humidity    wind
# 0      sunny     high    weak
# 1      sunny     high  strong
# 2   overcast     high    weak
# 3       rain     high    weak
# 4       rain   normal    weak
# 5       rain   normal  strong
# 6   overcast   normal  strong
# 7      sunny     high    weak
# 8      sunny   normal    weak
# 9       rain   normal    weak
# 10     sunny   normal  strong
# 11  overcast     high  strong
# 12  overcast   normal    weak
# 13      rain     high  strong

# %%
print(y)
# Out:
#    play
# 0    no
# 1    no
# 2   yes
# 3   yes
# 4   yes
# 5    no
# 6   yes
# 7    no
# 8   yes
# 9   yes
# 10  yes
# 11  yes
# 12  yes
# 13   no

# %% [markdown]
# ## 4. Train the classifier
#
# The next step is to train the classifier (decision tree) with the data. As you know, training is always necessary for supervised learning algorithms.

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17168\785551433.py in ?()
#       1 clf = DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X, y)
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1005         self : DecisionTreeClassifier
#    1006             Fitted estimator.
#    1007         """
#    1008
# -> 1009         super()._fit(
#    1010             X,
#    1011             y,
#    1012             sample_weight=sample_weight,
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     248             check_X_params = dict(
#     249                 dtype=DTYPE, accept_sparse="csc", force_all_finite=False
#     250             )
#     251             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 252             X, y = self._validate_data(
#     253                 X, y, validate_separately=(check_X_params, check_y_params)
#     254             )
#     255
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     641                 # :(
#     642                 check_X_params, check_y_params = validate_separately
#     643                 if "estimator" not in check_X_params:
#     644                     check_X_params = {**default_check_params, **check_X_params}
# --> 645                 X = check_array(X, input_name="X", **check_X_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1004                         )
#    1005                     array = xp.astype(array, dtype, copy=False)
#    1006                 else:
#    1007                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1008             except ComplexWarning as complex_warning:
#    1009                 raise ValueError(
#    1010                     "Complex data not supported\n{}\n".format(array)
#    1011                 ) from complex_warning
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     742         # Use NumPy API to support order
#     743         if copy is True:
#     744             array = numpy.array(array, order=order, dtype=dtype)
#     745         else:
# --> 746             array = numpy.asarray(array, order=order, dtype=dtype)
#     747
#     748         # At this point array is a NumPy ndarray. We convert it to an array
#     749         # container that is consistent with the input's namespace.
#
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'sunny'

# %% [markdown]
# When you run the code above, you should get the following error:
#
# ```
# ValueError: could not convert string to float: 'sunny'
# ```
#
# **The decision trees implemented in scikit-learn use only numerical features and these features are interpreted always as continuous numeric variables. *sunny, overcast and rain* are categorical features and they are not supported in scikit-learn.**
#
# The simpliest way to solve this, is to replace our categorical string values with numerical values. But, simply replacing the strings with numbers normally should be avoided. Because being considered as a continuous numerical feature, any coding you  use, will induce an order which simply does not exist in your data.
#
# For example coding ['sunny', 'overcast', 'rain'] with [1, 2, 3], would produce weird things like 'sunny' is lower than 'overcast', and if you average a 'sunny' and a 'rain' you will get a 'overcast'.
#
# But since it is the simpliest solution, we are going to do it anyway. You can always search the internet for better solutions.
#
# So let's install `category_encoders` to replace the categories with numeric values.

# %%
pip install --upgrade category_encoders
# Out:
# Requirement already satisfied: category_encoders in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from category_encoders) (1.5.0)
# Requirement already satisfied: scipy>=1.0.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: six in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in d:\files\school\ai\02_ai - graph search algorithms\.venv\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (24.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
print(X)
# Out:
#      outlook humidity    wind
# 0      sunny     high    weak
# 1      sunny     high  strong
# 2   overcast     high    weak
# 3       rain     high    weak
# 4       rain   normal    weak
# 5       rain   normal  strong
# 6   overcast   normal  strong
# 7      sunny     high    weak
# 8      sunny   normal    weak
# 9       rain   normal    weak
# 10     sunny   normal  strong
# 11  overcast     high  strong
# 12  overcast   normal    weak
# 13      rain     high  strong

# %%
print(feature_cols)
# Out:
# ['outlook', 'humidity', 'wind']

# %%
import category_encoders as ce

ce_ord = ce.OrdinalEncoder(cols = feature_cols)
X_cat = ce_ord.fit_transform(X)

# %%
print(X_cat)
# Out:
#     outlook  humidity  wind
# 0         1         1     1
# 1         1         1     2
# 2         2         1     1
# 3         3         1     1
# 4         3         2     1
# 5         3         2     2
# 6         2         2     2
# 7         1         1     1
# 8         1         2     1
# 9         3         2     1
# 10        1         2     2
# 11        2         1     2
# 12        2         2     1
# 13        3         1     2

# %% [markdown]
# Now we can try to train the classifier (decision tree) with the data.

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion = "entropy")
clf = clf.fit(X_cat, y)

# %% [markdown]
# ## 5. Visualize the decision tree
#
# Now we can use the packages from above (graphviz and pydotplus) to visualize our decision tree.

# %%
from io import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file = dot_data, filled = True, rounded = True,
                special_characters = True, feature_names = feature_cols, class_names=['no','yes'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png(), width = 550)

# %% [markdown]
# Remarks:
#
# - The algorithm keeps generating levels until the datasets are pure (entropy = 0).
# - Since scikit-learn works with continuous values, the conditions in the nodes are formulated as `feature <= some_other_value` with only two outcomes (true or false). In our example we had categorical values: *Outlook is sunny, overcast or rain*.

# %% [markdown]
# ## 6. Make predictions - Exercise
#
# We wanted to predict if John would play tennis on a rainy day with high humidity and weak wind. Can you first convert the features in number values and use the tree above to determine if John will play tennis?

# %%
# answer?
# [outlook, humidity, wind] = [ , , ]
# Will John play tennis? YES / NO

rediction = clf.predict([[3, 3, 3]])  
print(rediction)
# Out:
# ['no']
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# You can check yourself if your prediction was right.

# %%
prediction = clf.predict([[3, 1, 1]])                                         
print(prediction)
# Out:
# ['yes']
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 7. An extra feature temperature - Exercise
#
# In the resources you will find a file tennis2.csv with an extra feature. Can you use this file and predict if John will still  play tennis on a HOT rainy day with high humidity and weak wind?

# %%
# load dataset

tennis2_df = pd.read_csv("resources/tennis2.csv", sep=';')
print(tennis2_df)
# Out:
#     day   outlook  temp humidity    wind play
# 0    d1     sunny  mild     high    weak   no
# 1    d2     sunny  cool     high  strong  yes
# 2    d3  overcast   hot     high    weak  yes
# 3    d4      rain  mild     high    weak  yes
# 4    d5      rain  cool   normal    weak  yes
# 5    d6      rain  cool   normal  strong   no
# 6    d7  overcast  cool   normal  strong  yes
# 7    d8     sunny  mild     high    weak   no
# 8    d9     sunny  cool   normal    weak  yes
# 9   d10      rain  mild   normal    weak  yes
# 10  d11     sunny  mild   normal  strong  yes
# 11  d12  overcast  mild     high  strong  yes
# 12  d13  overcast   hot   normal    weak  yes
# 13  d14      rain  mild     high  strong   no

# %%
# print dataset
print(tennis2_df)

# %%
# split dataset in features and target variable
feature_cols2 = ['outlook', 'temp', 'humidity', 'wind']

x1 = tennis2_df[feature_cols2]
y1 = tennis2_df[['play']] # target variable

# %%
# encode the categories
import category_encoders as ce

ce_ord = ce.OrdinalEncoder(cols = feature_cols2)
X_cat1 = ce_ord.fit_transform(x1)
print(X_cat1)
print(feature_cols2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # encode the categories
#       2 import category_encoders as ce
# ----> 4 ce_ord = ce.OrdinalEncoder(cols = feature_cols2)
#       5 X_cat1 = ce_ord.fit_transform(x1)
#       6 print(X_cat1)
#
# NameError: name 'feature_cols2' is not defined

# %%
# print the encoded categories

# %%
# fit the classifier

clf1 = DecisionTreeClassifier(criterion = "entropy")
clf1 = clf.fit(X_cat1, y1)

# %%
# print the decision tree
dot_data = StringIO()
export_graphviz(clf1, out_file = dot_data, filled = True, rounded = True,
                special_characters = True, feature_names = feature_cols2, class_names=['no','yes'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png(), width = 550)

# %%
# make prediction
prediction = clf1.predict([[2,1,1,2]])
print(prediction)
# Out:
# ['yes']
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# Will John still play tennis on a HOT rainy day with high humidity and weak wind?
# answer
prediction2 = clf1.predict([[3,3,3,1]])
print(prediction2)
# Out:
# ['yes']
# d:\files\school\AI\02_AI - Graph Search Algorithms\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
